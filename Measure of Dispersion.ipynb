# %%
data=[]
num=int(input("enter the number of elements"))
for i in range(num):
  element=int(input("enter the elements"))
  data.append(element)
data
# Out:
# enter the number of elements5
# enter the elements1
# enter the elements2
# enter the elements3
# enter the elements4
# enter the elements5
# [1, 2, 3, 4, 5]

# %%
#Finding Range

minimum=maximum=data[0]
if num<=minimum:
  minimum=num
if num>=maximum:
  maximum=num
Range_value=maximum-minimum
print("Range(without using inbuilt function)",Range_value)


import numpy as np
maximum=np.max(data)
minimum=np.min(data)
Range_value=maximum-minimum
print("Range(with using inbuilt funtion)",Range_value)
# Out:
# Range(without using inbuilt function) 4
# Range(with using inbuilt funtion) 4

# %%
#Finding Variance

sum1=0
for i in data:
  sum1=sum1+i
mean_value=sum1/num
variance_value=sum((item-mean_value)**2 for item in data)/num
print("Variance(without using inbuilt function)",variance_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5aac3647881c> in <cell line: 7>()
#       5   sum1=sum1+i
#       6 mean_value=sum1/num
# ----> 7 variance_value=sum((val-mean_value)**2 for val in data)/num
#       8 print("Variance(without using inbuilt function)",variance_value)
#
# TypeError: 'int' object is not callable
